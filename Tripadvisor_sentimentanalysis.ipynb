# %%
import pandas as pd
import unicodecsv as csv
import nltk
import pandas as pd

from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize

import nltk
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier

import matplotlib.pyplot as plt
# %matplotlib inline

import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# C:\Users\faraz\Anaconda3\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
df1 = pd.read_excel("Tripadvisor_New.xlsx")

# %%
df = list(df1['Review Text'].values)

# %%
scores = []
sid = SentimentIntensityAnalyzer()
for review in df[:50]:
    ss = sid.polarity_scores(review)
    scores.append((review, ss['compound']))
df = pd.DataFrame(scores, columns=['Review', 'Score'])
df.to_csv('Sentiment_scores.csv', index=False)

# %%
# Out:
#                                                Review   Score
# 0   Stayed at the Artmore for my birthday weekend....  0.9546
# 1   The hotel is a little dated, but the room was ...  0.9771
# 2   This was a truly nice, little, quaint and pop-...  0.9774
# 3   The Art Center MARTA station is directly acros... -0.7140
# 4   I travel from South Africa to the USA 3-4 time...  0.7306
# 5   We had to do an overnight in Atlanta and found...  0.9468
# 6   What canâ€™t I say about my stay. Everything w...  0.9786
# 7   I was having one of those horrible days, then ...  0.9836
# 8   The Hotel was okay, but I was really sad that ... -0.7343
# 9   The Artmore is in a great downtown location. I...  0.9545
# 10  First off I had no clue there was a $100.00 fe... -0.4349
# 11  This is a charming, historic hotel convenientl...  0.7681
# 12  It's easy to drive right by the Artmore Hotel,...  0.9791
# 13  Super downtown location, great suite.  The bed...  0.9804
# 14  Great rooms, service, atmosphere and staff! Th...  0.9112
# 15  I had such an excellent time at the Artmore Ho...  0.8824
# 16  I spent two nights in a second floor room for ...  0.8213
# 17  The Artmore is a really nice hotel with reason...  0.9616
# 18  Hotel overall a bit tired and would benefit fr...  0.7419
# 19  The hotel is very cozy. I loved the room dÃ©co...  0.9557
# 20  Rooms are spacious, clean and quiet. Train sta...  0.8516
# 21  Room average in cleanliness, non working elect... -0.7717
# 22  Great hotel walking distance from High Museum ...  0.9701
# 23  The hotel is dingy. staff is nice, but service...  0.9256
# 24  The Artmore Hotel is a decent mid-range accomm...  0.7133
# 25  Excellent atmosphere and intimate. Our family ...  0.7919
# 26  The outdoor bar space is lovely but I got zero...  0.6705
# 27  I had my bachelorette party in Atlanta and we ...  0.9650
# 28  Artmore hotel was recommended by our family me...  0.9670
# 29  Such a great hotel experience! Love the art, t...  0.9811
# 30  We were only there for 1 night so we didnâ€™t ...  0.8402
# 31  This is my first time in Atlanta and the staff...  0.9583
# 32  Rooms were very & clean and comfortable. Excel...  0.9209
# 33  Thank you again for being so accommodating to ...  0.9437
# 34  Great location...great Walking distance to lot...  0.9169
# 35  This is the 5th stay for me at the Artmore.  I...  0.9741
# 36  Thoroughly enjoyed our stay in a 2 bedroom sui...  0.7574
# 37  This is a renovation of an old building into a...  0.9752
# 38  A management and authority issue at this hotel... -0.4480
# 39  Staff was great. Alicia was the bomb. So helpf...  0.9821
# 40  The valet staff was extremely rude when I aske... -0.6672
# 41  Comfortable, convenient hotel. Exceptionally f...  0.9288
# 42  From the valet Justin, check-in with Shane and...  0.9442
# 43  This is a wonderful hotel with nicely appointe...  0.9949
# 44  We loved the decor and cleanliness of this pla...  0.9874
# 45  I booked a room with a king bed and a couch th... -0.1531
# 46  The Artmore is an older hotel property in MId ...  0.9818
# 47  Have stayed here numerous times in the past, f...  0.0598
# 48  I have stayed at the Artmore a number of times...  0.7845
# 49  We spent the weekend here in celebration of ou...  0.9808
